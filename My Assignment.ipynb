# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **ADEYEMI ISRAEL
#
# I want be a reknown Data Scientist working for a Fortune500 company.

# %% [markdown]
# *I am interested in data science because I want to contribute my quota to the growth of the world economy. I also want to be successful in life.

# %% [markdown]
# ### The code will give random height and weight values. It will also produce a scatter plot.

# %%
import matplotlib.pyplot as plt
import numpy as np
height = np.round(np.random.normal(1.75, 0.20, 5000), 2)
weight = np.round(np.random.normal(60.32, 15, 5000), 2)
np_city = np.column_stack((weight,height))
plt.scatter(height, weight)
plt.show()

# %% [markdown]
# Strikethrough :
# ~~I am a footballer.~~
#
# Syntax highlighting :
# Your `skills` are improving by the week!
#
# Numbered list :
# 1. One
# 2. Two
# 3. Three
#
# Horizontal Rule :
# ***
# ___
